# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'Bike_Sharing_Data/train.csv'
train = pd.read_csv(path)

train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %%
train[train['hour_bef_ozone'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 14      28     1                  20.0                     0.0
# 44      76    17                  21.7                     0.0
# 46      78     1                  12.2                     0.0
# 84     130     1                   9.4                     0.0
# 122    181    16                  26.2                     0.0
# ...    ...   ...                   ...                     ...
# 1283  1941     1                  16.6                     0.0
# 1322  1994     1                  15.1                     0.0
# 1329  2005     1                  17.7                     0.0
# 1361  2047     1                  12.6                     0.0
# 1391  2086     1                  11.5                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 14                   1.8               58.0               2000.0
# 44                   3.0               35.0               2000.0
# ...

# %%
features = train.columns.drop(['id', 'hour', 'count'])

for feature in features:
    mean = train[feature].mean()
    train[feature] = train[feature].fillna(mean)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1459 non-null   float64
#  3   hour_bef_precipitation  1459 non-null   float64
#  4   hour_bef_windspeed      1459 non-null   float64
#  5   hour_bef_humidity       1459 non-null   float64
#  6   hour_bef_visibility     1459 non-null   float64
#  7   hour_bef_ozone          1459 non-null   float64
#  8   hour_bef_pm10           1459 non-null   float64
#  9   hour_bef_pm2.5          1459 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %%
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm') # This line plots nicely visualized matrix of correlation
# Out:
# <style type="text/css">
# #T_84575_row0_col0, #T_84575_row1_col1, #T_84575_row2_col2, #T_84575_row3_col3, #T_84575_row4_col4, #T_84575_row5_col5, #T_84575_row6_col6, #T_84575_row7_col7, #T_84575_row8_col8, #T_84575_row9_col9, #T_84575_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_84575_row0_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_84575_row0_col2, #T_84575_row0_col7, #T_84575_row8_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_84575_row0_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_84575_row0_col4, #T_84575_row10_col9 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_84575_row0_col5, #T_84575_row6_col7, #T_84575_row7_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_84575_row0_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_84575_row0_col8, #T_84575_row3_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# ...
